# %% [markdown]
# ### Arrays
# immutable
# initialize , pop , edit an item , delete ,
#
# dynamic and static
# python on arrays

# %%
print("testing")
# Out:
# testing

# %%
print("testing")
# Out:
# testing

# %%
print(3)
# Out:
# 3
