# %% [markdown]
# # Arrays
# immutable
# initialize , pop , edit an item , delete ,
#
# dynamic and static
# python on arrays

# %%
print("testing")
# Out:
# testing

# %%
print("testing")
# Out:
# testing

# %%
print(3)
# Out:
# 3

# %% [markdown]
# # List

# %%
print("List")

# %% [markdown]
# # Tuple

# %%
print("Tuple")

# %% [markdown]
# # Set

# %%
print("set")

# %% [markdown]
# # Dict

# %%
print("set")

# %% [markdown]
# # Deque

# %%
print("set")

# %% [markdown]
# # Counter

# %%
print("set")

# %% [markdown]
# # Queue / PriorityQueue

# %%
print("set")

# %% [markdown]
# # Stack

# %%
print("set")

# %% [markdown]
# #  Queue

# %% [markdown]
# # LinkedList

# %%
x = 1

# %% [markdown]
# #  Trees

# %% [markdown]
# #   Graphs

# %% [markdown]
# # Heap

# %%
print("set")
