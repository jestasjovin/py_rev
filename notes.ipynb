# %% [markdown]
# # Take aways

# %% [markdown]
# modular design : single core app with mini apps
# single source of truth
# sys architectire from data and work flow
# desicion making on each line of code
# documentation : on impacts before and after
#
# communication
#
# github working styles : depemding on the nature of project and people
# - reusable /ready made use em
